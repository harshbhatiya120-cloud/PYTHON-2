# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("auto-mpg.csv").squeeze()
print(df)
df.sample()
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 df1=pd.read_csv("auto-mpg.csv").squeeze()
# ----> 4 print(df)
#       5 df.sample()
#       6 df.shape
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
 df.isna().sum
# Out:
# <bound method DataFrame.sum of        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# ...

# %%
df[df['horsepower']=='?'].shape[0]
# Out:
# 6

# %%
df.loc[5:15]
df.iloc[5:15]
df[4:15]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# 13  14.0          8         455.0        225    3086          10.0
# 14  24.0          4         113.0         95    2372          15.0
#
#     model year  origin                 car name
# 4           70       1              ford torino
# 5           70       1         ford galaxie 500
# ...

# %%
df['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df['mpg'].loc[4]
df['mpg'][5]
# Out:
# np.float64(15.0)

# %%
df[['mpg']].loc[4]
# Out:
# mpg    17.0
# Name: 4, dtype: float64

# %%
df['mpg'].shape
# Out:
# (398,)

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include=[np.number])
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(exclude=[np.number])
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 77      1
# 132     1
# 64      1
# 116     1
# 82      1
# Name: count, Length: 94, dtype: int64

# %%
df['car name'].value_counts()
# Out:
# car name
# ford pinto             6
# ford maverick          5
# amc matador            5
# toyota corolla         5
# amc hornet             4
#                       ..
# amc concord dl         1
# volkswagen rabbit l    1
# mazda glc custom l     1
# mazda glc custom       1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64

# %%
df.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
df.describe(percentiles=[.30,.40,.60])
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 30%     18.000000    4.000000    112.000000  2301.000000     14.200000
# 40%     20.000000    4.000000    122.000000  2580.600000     14.800000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 60%     25.000000    6.000000    200.000000  3085.200000     16.000000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 30%     73.000000    1.000000
# 40%     75.000000    1.000000
# 50%     76.000000    1.000000
# ...

# %%
df[['mpg','cylinders']].describe()
# Out:
#               mpg   cylinders
# count  398.000000  398.000000
# mean    23.514573    5.454774
# std      7.815984    1.701004
# min      9.000000    3.000000
# 25%     17.500000    4.000000
# 50%     23.000000    4.000000
# 75%     29.000000    8.000000
# max     46.600000    8.000000

# %%
df.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
data={'Region':['North','North','South','South'],
     'city':['New york','Los angeless','Miami','Houston'],
     'population':[8.4,3.9,0.4,2.3]}
df=pd.DataFrame(data)
df
# Out:
#   Region          city  population
# 0  North      New york         8.4
# 1  North  Los angeless         3.9
# 2  South         Miami         0.4
# 3  South       Houston         2.3

# %%
df.nunique()
# Out:
# Region        2
# city          4
# population    4
# dtype: int64

# %%
print(df['Region'].unique())
# Out:
# ['North' 'South']

# %%
print(df['city'].unique())
# Out:
# ['New york' 'Los angeless' 'Miami' 'Houston']

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df1,figsize=[15,15],marker='o',alpha=0.5,diagonal='kde')
plt.show()

# %%
from pandas.plotting import parallel_coordinates
df=pd.read_csv('auto-mpg.csv')
pll=parallel_coordinates(df,'displacement',cols=[])
