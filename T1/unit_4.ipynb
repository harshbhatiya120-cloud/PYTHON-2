# %%
import pandas as pd
df=pd.read_csv("Book2.csv")
print(df)
# Out:
#     15  49
# 0   23  63
# 1   18  58
# 2   23  60
# 3   24  58
# 4   22  61
# 5   22  60
# 6   19  63
# 7   19  60
# 8   16  52
# 9   24  62
# 10  11  30
# 11  24  59
# 12  16  49
# 13  23  68
