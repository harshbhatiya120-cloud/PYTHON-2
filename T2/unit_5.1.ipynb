# %%
import pandas as pd 
df=pd.read_csv("tshirt (1).csv")
df
# Out:
#     Height  Wight Size
# 0      158     58    M
# 1      158     59    M
# 2      158     63    M
# 3      160     59    M
# 4      160     60    M
# 5      163     60    M
# 6      163     61    M
# 7      160     64    L
# 8      163     64    L
# 9      165     61    L
# 10     165     62    L
# 11     165     65    L
# 12     168     62    L
# 13     168     63    L
# 14     168     66    L
# 15     170     63    L
# 16     170     64    L
# 17     170     68    L

# %%
x=df.iloc[:,0:2]
y=df['Size']
print(x.shape)
print(y.shape)
# Out:
# (18, 2)
# (18,)

# %%
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
#print(x_train.shape)
#print(x_test.shape)
#print(y_train.shape)
#print(y_test.shape)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model.fit(x,y)
prediction=model.predict(x)
print(prediction)
# Out:
# ['M' 'M' 'M' 'M' 'M' 'M' 'L' 'M' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L']

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y,prediction)
print(cm)
# Out:
# [[10  1]
#  [ 1  6]]

# %%
import matplotlib.pyplot as plt
from sklearn import metrics 
cm_disp=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=["x","y"])
cm_disp.plot()
plt.show()

# %%
TN=cm[0][0]
FP=cm[0][1]
FN=cm[1][0]
TP=cm[1][1]
print(TN,FP,FN,TP)
# Out:
# 10 1 1 6

# %%
Model_Accuracy=(TP+TN)/(TP+FP+FN+TN)
print(f"Accuracy Score :",Model_Accuracy)
# Out:
# Accuracy Score : 0.8888888888888888

# %% [markdown]
# # aptitudecomnication
